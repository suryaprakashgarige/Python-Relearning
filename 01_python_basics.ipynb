# %% [markdown]
# **This is the Code I am writing in Python and using Google Colab.**
#
# I am learning the python again to improve my fundamentals for upcoming my projects about to build the Machine Learning Models.

# %%
A= "Anji"
print(A)
print(A.lower())
print(A.upper())
# Out:
# Anji
# anji
# ANJI

# %%
X = input("Enter You Name:")
Y = input("Enter Your age:")
print(X, "is", Y, "Years old.")
# Out:
# Enter You Name:Surya
# Enter Your age:19
# Surya is 19 Years old.

# %%
v1 = 10
print(v1)
print(type(v1))
# Out:
# 10
# <class 'int'>

# %%
k = 'Karun'
t = input('Enter any word: ');
print(k, 'is a', t)
# Out:
# Enter any word: Topper
# Karun is a Topper

# %% [markdown]
# In the below code, I am giving the input a number and by default the python taking it as a string and so, I converted the str into int. This small code helps me in the future while writing the code and taking the numerical vaules as Input and then perform the numerical problems.

# %%
a = 10
b = input('Enter the any Number: ')
print(b)
print(type(b))
b = int(b)
print(type(b))
print(a+b)
# Out:
# Enter the any Number: 203
# 203
# <class 'str'>
# <class 'int'>
# 213
